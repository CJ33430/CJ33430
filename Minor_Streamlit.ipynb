# %% [markdown]
# <a href="https://colab.research.google.com/github/ChaitanyaJakate/ChaitanyaJ33/blob/main/Minor_Streamlit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/jobs.csv')

# %%
df
# Out:
#        Unnamed: 0                    Job Salary Job Experience Required  \
# 0               0   Not Disclosed by Recruiter               5 - 10 yrs
# 1               1   Not Disclosed by Recruiter                2 - 5 yrs
# 2               2   Not Disclosed by Recruiter                0 - 1 yrs
# 3               3       2,00,000 - 4,00,000 PA.               0 - 5 yrs
# 4               4   Not Disclosed by Recruiter                2 - 5 yrs
# ...           ...                           ...                     ...
# 27005       29995   Not Disclosed by Recruiter               9 - 12 yrs
# 27006       29996   Not Disclosed by Recruiter                1 - 5 yrs
# 27007       29997   Not Disclosed by Recruiter                4 - 6 yrs
# 27008       29998   Not Disclosed by Recruiter               5 - 10 yrs
# 27009       29999   Not Disclosed by Recruiter                2 - 7 yrs
#
#                                               Key Skills  \
# ...

# %%
len(df['Job Title'].unique())
# Out:
# 630

# %%
len(df['Key Skills'].unique())
# Out:
# 25292

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Key Skills']=le.fit_transform(df[['Key Skills']])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df['Job Title']=le.fit_transform(df[['Job Title']])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df
# Out:
#        Unnamed: 0                    Job Salary Job Experience Required  \
# 0               0   Not Disclosed by Recruiter               5 - 10 yrs
# 1               1   Not Disclosed by Recruiter                2 - 5 yrs
# 2               2   Not Disclosed by Recruiter                0 - 1 yrs
# 3               3       2,00,000 - 4,00,000 PA.               0 - 5 yrs
# 4               4   Not Disclosed by Recruiter                2 - 5 yrs
# ...           ...                           ...                     ...
# 27005       29995   Not Disclosed by Recruiter               9 - 12 yrs
# 27006       29996   Not Disclosed by Recruiter                1 - 5 yrs
# 27007       29997   Not Disclosed by Recruiter                4 - 6 yrs
# 27008       29998   Not Disclosed by Recruiter               5 - 10 yrs
# 27009       29999   Not Disclosed by Recruiter                2 - 7 yrs
#
#        Key Skills                               Role Category  \
# ...

# %%
df['Job Salary'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 27010 entries, 0 to 27009
# Series name: Job Salary
# Non-Null Count  Dtype
# --------------  -----
# 27010 non-null  object
# dtypes: object(1)
# memory usage: 211.1+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# Job Salary                 0
# Job Experience Required    0
# Key Skills                 0
# Role Category              0
# Functional Area            0
# Industry                   0
# Job Title                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27010 entries, 0 to 27009
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               27010 non-null  int64
#  1   Job Salary               27010 non-null  object
#  2   Job Experience Required  27010 non-null  object
#  3   Key Skills               27010 non-null  int64
#  4   Role Category            27010 non-null  object
#  5   Functional Area          27010 non-null  object
#  6   Industry                 27010 non-null  object
#  7   Job Title                27010 non-null  int64
# dtypes: int64(3), object(5)
# memory usage: 1.6+ MB

# %%
len(df['Job Experience Required'].unique())
# Out:
# 246

# %%
df['Role Category'].unique()
# Out:
# array(['Advertising', 'Retail Sales', 'R&D',
#        'Admin/Maintenance/Security/Datawarehousing',
#        'Programming & Design', 'Institutional Sales', 'Voice',
#        'Corporate Planning/Consulting/Strategy', 'Operations',
#        'Online/Digital Marketing', 'Engineering Design', 'Accounts',
#        'Retail/Personal Banking', 'QA/Testing/Documentation',
#        'Project Management', 'Logistics', 'Technical Support',
#        'Senior Management', 'Back Office/Web/Transaction Processing',
#        'Content Development', 'HR/ Recruitment / IR', 'Health & Fitness',
#        'Corporate Sales', 'Architectural Services',
#        'Front Office/Customer Care',
#        'Production/Manufacturing/Maintenance', 'Creative',
#        'Channel Sales', 'Sales Support',
#        'System Design/Implementation/ERP/CRM', 'Quality',
#        'Analytics & BI', 'Other', 'Finance/Audit', 'Public Relations',
#        'University Level', 'Drug Regulatory Affairs/Documentation',
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder(sparse_output=False,handle_unknown='ignore')

# %%
df['Job Experience Required']=ohe.fit_transform(df[['Job Experience Required']])

# %%
df['Role Category']=ohe.fit_transform(df[['Role Category']])

# %%
df['Industry'].unique()
# Out:
# array(['Advertising, PR, MR, Event Management',
#        'IT-Software, Software Services', 'Recruitment, Staffing',
#        'Real Estate, Property',
#        'Courier, Transportation, Freight , Warehousing',
#        'BPO, Call Centre, ITeS', 'IT-Software / Software Services',
#        'Industrial Products, Heavy Machinery',
#        'Textiles, Garments, Accessories', 'Insurance',
#        'Pharma, Biotech, Clinical Research', 'Animation, Gaming',
#        'FMCG, Foods, Beverage', 'Security, Law Enforcement',
#        'Strategy, Management Consulting Firms', 'Internet, Ecommerce',
#        'Education, Teaching, Training', 'Media, Entertainment, Internet',
#        'Aviation, Aerospace, Aeronautical', 'Telcom, ISP',
#        'Facility Management',
#        'Travel , Hotels , Restaurants , Airlines , Railways',
#        'Oil and Gas, Energy, Power, Infrastructure',
#        'Banking, Financial Services, Broking',
#        'Construction, Engineering, Cement, Metals',
# ...

# %%
df['Job Salary'].unique()
# Out:
# array([' Not Disclosed by Recruiter ', '2,00,000 - 4,00,000 PA.',
#        '7,00,000 - 17,00,000 PA.', ..., ' As per Industry norm ',
#        'INR 14,00,000 - 15,00,000 PA.', 'INR 7,00,000 - 8,00,000 PA.'],
#       dtype=object)

# %%
df['Industry']=ohe.fit_transform(df[['Industry']])
df['Job Salary']=ohe.fit_transform(df[['Job Salary']])

# %%
df
# Out:
#        Unnamed: 0  Job Salary  Job Experience Required  Key Skills  \
# 0               0         0.0                      0.0        8722
# 1               1         0.0                      0.0       19762
# 2               2         0.0                      0.0        3469
# 3               3         0.0                      0.0       14102
# 4               4         0.0                      0.0       18986
# ...           ...         ...                      ...         ...
# 27005       29995         0.0                      0.0        6110
# 27006       29996         0.0                      0.0       13047
# 27007       29997         0.0                      0.0        3967
# 27008       29998         0.0                      0.0       12919
# 27009       29999         0.0                      0.0       10338
#
#        Role Category                                    Functional Area  \
# 0                0.0  Marketing , Advertising , MR , PR , Media Plan...
# ...

# %%
df['Functional Area'].unique()
# Out:
# array(['Marketing , Advertising , MR , PR , Media Planning',
#        'Sales , Retail , Business Development',
#        'Engineering Design , R&D',
#        'IT Software - Application Programming , Maintenance',
#        'IT Software - QA & Testing',
#        'ITES , BPO , KPO , LPO , Customer Service , Operations',
#        'Strategy , Management Consulting , Corporate Planning',
#        'IT Software - eCommerce , Internet Technologies',
#        'Accounts , Finance , Tax , Company Secretary , Audit',
#        'Financial Services , Banking , Investments , Insurance',
#        'IT Software - DBA , Datawarehousing',
#        'IT Software - Network Administration , Security',
#        'Purchase / Logistics / Supply Chain',
#        'IT Hardware , Technical Support , Telecom Engineering',
#        'IT Software - Mobile', 'Journalism , Editing , Content',
#        'HR , Recruitment , Administration , IR',
#        'Beauty / Fitness / Spa Services',
# ...

# %%
df['Functional Area']=ohe.fit_transform(df[['Functional Area']])

# %%
df
# Out:
#        Unnamed: 0  Job Salary  Job Experience Required  Key Skills  \
# 0               0         0.0                      0.0        8722
# 1               1         0.0                      0.0       19762
# 2               2         0.0                      0.0        3469
# 3               3         0.0                      0.0       14102
# 4               4         0.0                      0.0       18986
# ...           ...         ...                      ...         ...
# 27005       29995         0.0                      0.0        6110
# 27006       29996         0.0                      0.0       13047
# 27007       29997         0.0                      0.0        3967
# 27008       29998         0.0                      0.0       12919
# 27009       29999         0.0                      0.0       10338
#
#        Role Category  Functional Area  Industry  Job Title
# 0                0.0              0.0       0.0        385
# ...

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df
# Out:
#        Job Salary  Job Experience Required  Key Skills  Role Category  \
# 0             0.0                      0.0        8722            0.0
# 1             0.0                      0.0       19762            0.0
# 2             0.0                      0.0        3469            0.0
# 3             0.0                      0.0       14102            0.0
# 4             0.0                      0.0       18986            0.0
# ...           ...                      ...         ...            ...
# 27005         0.0                      0.0        6110            0.0
# 27006         0.0                      0.0       13047            0.0
# 27007         0.0                      0.0        3967            0.0
# 27008         0.0                      0.0       12919            0.0
# 27009         0.0                      0.0       10338            0.0
#
#        Functional Area  Industry  Job Title
# 0                  0.0       0.0        385
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.drop(columns=['Job Title']),df['Job Title'],test_size=0.2,random_state=42)

# %%
x_train
# Out:
#        Job Salary  Job Experience Required  Key Skills  Role Category  \
# 24493         0.0                      0.0       22222            0.0
# 5195          0.0                      0.0       21131            0.0
# 13138         0.0                      0.0        8712            0.0
# 2273          0.0                      0.0        1726            0.0
# 3699          0.0                      0.0       22297            0.0
# ...           ...                      ...         ...            ...
# 21575         0.0                      0.0       16098            0.0
# 5390          0.0                      0.0        8389            0.0
# 860           0.0                      0.0       10651            0.0
# 15795         0.0                      0.0       16772            0.0
# 23654         0.0                      0.0        7907            0.0
#
#        Functional Area  Industry
# 24493              0.0       0.0
# 5195               0.0       0.0
# ...

# %%
y_train
# Out:
# 24493    539
# 5195     581
# 13138    240
# 2273     262
# 3699     563
#         ...
# 21575    376
# 5390      23
# 860      539
# 15795     57
# 23654    240
# Name: Job Title, Length: 21608, dtype: int64

# %%
x_train.shape,y_train.shape
# Out:
# ((21608, 6), (21608,))

# %%
x_test.shape,y_test.shape
# Out:
# ((5402, 6), (5402,))

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(bootstrap=True,n_estimators=100)
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rfc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.2606442058496853

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from imblearn.over_sampling import SMOTE
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
import pandas as pd

# Load the dataset

jobs_df = pd.read_csv('/content/jobs.csv')

# Display the first few rows and basic info to understand the structure
jobs_df_info = jobs_df.info()
jobs_df_head = jobs_df.head()

jobs_df_info, jobs_df_head

# Preprocessing
# We'll use Tfidf for Key Skills and OneHotEncoder for categorical features

# Columns to encode and vectorize
categorical_columns = ['Role Category', 'Functional Area', 'Industry', 'Job Experience Required']
text_column = 'Key Skills'

# Features (excluding 'Unnamed: 0', 'Job Salary', and target 'Job Title')
X = jobs_df.drop(columns=['Unnamed: 0', 'Job Title', 'Job Salary'])
y = jobs_df['Job Title']

y.unique().shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27010 entries, 0 to 27009
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               27010 non-null  int64
#  1   Job Salary               27010 non-null  object
#  2   Job Experience Required  27010 non-null  object
#  3   Key Skills               27010 non-null  object
#  4   Role Category            27010 non-null  object
#  5   Functional Area          27010 non-null  object
#  6   Industry                 27010 non-null  object
#  7   Job Title                27010 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 1.6+ MB
# (630,)

# %%
# Train-test split

# Define transformers
categorical_transformer = OneHotEncoder(handle_unknown='ignore')
text_transformer = TfidfVectorizer(max_features=500)

# Preprocess pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_columns),
        ('text', text_transformer, text_column)
    ])

# Use SMOTE to handle class imbalance
smote = SMOTE(random_state=42)

'''# Random Forest model pipeline
rf_pipeline = make_pipeline(
    preprocessor,
    RandomForestClassifier(random_state=42)
)

# Gradient Boosting model pipeline
gb_pipeline = make_pipeline(
    preprocessor,
    GradientBoostingClassifier(random_state=42)
)

# Logistic Regression model pipeline
lr_pipeline = make_pipeline(
    preprocessor,
    LogisticRegression(max_iter=1000, random_state=42)
)'''

# Filter out job titles that appear fewer than 2 times
min_samples = 2
job_title_counts = jobs_df['Job Title'].value_counts()
valid_job_titles = job_title_counts[job_title_counts >= min_samples].index
filtered_jobs_df = jobs_df[jobs_df['Job Title'].isin(valid_job_titles)]

# Update features (X) and target (y) with filtered data
X_filtered = filtered_jobs_df.drop(columns=['Unnamed: 0', 'Job Title', 'Job Salary'])
y_filtered = filtered_jobs_df['Job Title']

# Train-test split again with filtered data
X_train_f, X_test_f, y_train_f, y_test_f = train_test_split(X_filtered, y_filtered, test_size=0.2, random_state=42, stratify=y_filtered)

# Train models again
'''rf_pipeline.fit(X_train_f, y_train_f)
y_pred_rf_f = rf_pipeline.predict(X_test_f)
rf_accuracy_f = accuracy_score(y_test_f, y_pred_rf_f)'''

'''gb_pipeline.fit(X_train_f, y_train_f)
y_pred_gb_f = gb_pipeline.predict(X_test_f)
gb_accuracy_f = accuracy_score(y_test_f, y_pred_gb_f)'''

'''lr_pipeline.fit(X_train_f, y_train_f)
y_pred_lr_f = lr_pipeline.predict(X_test_f)
lr_accuracy_f = accuracy_score(y_test_f, y_pred_lr_f)'''

# Return accuracies of the models
#rf_accuracy_f gb_accuracy_f #lr_accuracy_f
#gb_accuracy_f
# Out:
# 'lr_pipeline.fit(X_train_f, y_train_f)\ny_pred_lr_f = lr_pipeline.predict(X_test_f)\nlr_accuracy_f = accuracy_score(y_test_f, y_pred_lr_f)'

# %%
# Train-test split

# Define transformers
categorical_transformer = OneHotEncoder(handle_unknown='ignore')
text_transformer = TfidfVectorizer(max_features=500)

# Preprocess pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_columns),
        ('text', text_transformer, text_column)
    ])

# Use SMOTE to handle class imbalance
smote = SMOTE(random_state=42)

'''# Random Forest model pipeline
rf_pipeline = make_pipeline(
    preprocessor,
    RandomForestClassifier(random_state=42)
)

# Gradient Boosting model pipeline
gb_pipeline = make_pipeline(
    preprocessor,
    GradientBoostingClassifier(random_state=42)
)

# Logistic Regression model pipeline
lr_pipeline = make_pipeline(
    preprocessor,
    LogisticRegression(max_iter=1000, random_state=42)
)'''

# Filter out job titles that appear fewer than 2 times
min_samples = 2
job_title_counts = jobs_df['Job Title'].value_counts()
valid_job_titles = job_title_counts[job_title_counts >= min_samples].index
filtered_jobs_df = jobs_df[jobs_df['Job Title'].isin(valid_job_titles)]

# Update features (X) and target (y) with filtered data
X_filtered = filtered_jobs_df.drop(columns=['Unnamed: 0', 'Job Title', 'Job Salary'])
y_filtered = filtered_jobs_df['Job Title']

# Train-test split again with filtered data
X_train_f, X_test_f, y_train_f, y_test_f = train_test_split(X_filtered, y_filtered, test_size=0.2, random_state=42, stratify=y_filtered)

# Train models again
'''rf_pipeline.fit(X_train_f, y_train_f)
y_pred_rf_f = rf_pipeline.predict(X_test_f)
rf_accuracy_f = accuracy_score(y_test_f, y_pred_rf_f)'''

'''gb_pipeline.fit(X_train_f, y_train_f)
y_pred_gb_f = gb_pipeline.predict(X_test_f)
gb_accuracy_f = accuracy_score(y_test_f, y_pred_gb_f)'''

'''lr_pipeline.fit(X_train_f, y_train_f)
y_pred_lr_f = lr_pipeline.predict(X_test_f)
lr_accuracy_f = accuracy_score(y_test_f, y_pred_lr_f)'''

# Return accuracies of the models
#rf_accuracy_f gb_accuracy_f #lr_accuracy_f
#gb_accuracy_f

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras import layers, models
from keras.layers import Dense

# %%
model = models.Sequential([
    layers.InputLayer(input_shape=(7513,)),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(630, activation='softmax')
])

# Compile and train the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train_f, y_train_f, epochs=10, validation_data=(X_train_f, y_test_f))

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_train_f, y_test_f)
print(f"Test accuracy: {test_accuracy}")
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-017f03f58032> in <cell line: 11>()
#       9 # Compile and train the model
#      10 model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# ---> 11 model.fit(X_train_f, y_train_f, epochs=10, validation_data=(X_train_f, y_test_f))
#      12
#      13 # Evaluate the model
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
# ...

# %%
# Train-test split

# Define transformers
categorical_transformer = OneHotEncoder(handle_unknown='ignore')
text_transformer = TfidfVectorizer(max_features=500)

# Preprocess pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_columns),
        ('text', text_transformer, text_column)
    ])

# Use SMOTE to handle class imbalance
# smote = SMOTE(random_state=42)

'''# Random Forest model pipeline
rf_pipeline = make_pipeline(
    preprocessor,
    RandomForestClassifier(random_state=42)
)

# Gradient Boosting model pipeline
gb_pipeline = make_pipeline(
    preprocessor,
    GradientBoostingClassifier(random_state=42)
)

# Logistic Regression model pipeline
lr_pipeline = make_pipeline(
    preprocessor,
    LogisticRegression(max_iter=1000, random_state=42)
)'''

# Filter out job titles that appear fewer than 2 times
min_samples = 2
job_title_counts = jobs_df['Job Title'].value_counts()
valid_job_titles = job_title_counts[job_title_counts >= min_samples].index
filtered_jobs_df = jobs_df[jobs_df['Job Title'].isin(valid_job_titles)]

# Update features (X) and target (y) with filtered data
X_filtered = filtered_jobs_df.drop(columns=['Unnamed: 0', 'Job Title', 'Job Salary'])
y_filtered = filtered_jobs_df['Job Title']

# Train-test split again with filtered data
X_train_f, X_test_f, y_train_f, y_test_f = train_test_split(X_filtered, y_filtered, test_size=0.2, random_state=42, stratify=y_filtered)

# Preprocess the data using the preprocessor
X_train_f = preprocessor.fit_transform(X_train_f)
X_test_f = preprocessor.transform(X_test_f)

# Train models again
'''rf_pipeline.fit(X_train_f, y_train_f)
y_pred_rf_f = rf_pipeline.predict(X_test_f)
rf_accuracy_f = accuracy_score(y_test_f, y_pred_rf_f)'''

'''gb_pipeline.fit(X_train_f, y_train_f)
y_pred_gb_f = gb_pipeline.predict(X_test_f)
gb_accuracy_f = accuracy_score(y_test_f, y_pred_gb_f)'''

'''lr_pipeline.fit(X_train_f, y_train_f)
y_pred_lr_f = lr_pipeline.predict(X_test_f)
lr_accuracy_f = accuracy_score(y_test_f, y_pred_lr_f)'''

# Return accuracies of the models
#rf_accuracy_f gb_accuracy_f #lr_accuracy_f
#gb_accuracy_f
# Out:
# 'lr_pipeline.fit(X_train_f, y_train_f)\ny_pred_lr_f = lr_pipeline.predict(X_test_f)\nlr_accuracy_f = accuracy_score(y_test_f, y_pred_lr_f)'

# %%
# Train-test split

# Define transformers
categorical_transformer = OneHotEncoder(handle_unknown='ignore')
text_transformer = TfidfVectorizer(max_features=500)

# Preprocess pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_columns),
        ('text', text_transformer, text_column)
    ])

# Use SMOTE to handle class imbalance
# smote = SMOTE(random_state=42)

'''# Random Forest model pipeline
rf_pipeline = make_pipeline(
    preprocessor,
    RandomForestClassifier(random_state=42)
)

# Gradient Boosting model pipeline
gb_pipeline = make_pipeline(
    preprocessor,
    GradientBoostingClassifier(random_state=42)
)

# Logistic Regression model pipeline
lr_pipeline = make_pipeline(
    preprocessor,
    LogisticRegression(max_iter=1000, random_state=42)
)'''

# Filter out job titles that appear fewer than 2 times
min_samples = 2
job_title_counts = jobs_df['Job Title'].value_counts()
valid_job_titles = job_title_counts[job_title_counts >= min_samples].index
filtered_jobs_df = jobs_df[jobs_df['Job Title'].isin(valid_job_titles)]

# Update features (X) and target (y) with filtered data
X_filtered = filtered_jobs_df.drop(columns=['Unnamed: 0', 'Job Title', 'Job Salary'])
y_filtered = filtered_jobs_df['Job Title']

# Train-test split again with filtered data
X_train_f, X_test_f, y_train_f, y_test_f = train_test_split(X_filtered, y_filtered, test_size=0.2, random_state=42, stratify=y_filtered)

# Preprocess the data using the preprocessor
X_train_f = preprocessor.fit_transform(X_train_f) # Fit and transform X_train_f
X_test_f = preprocessor.transform(X_test_f) # Transform X_test_f

model = models.Sequential([
    layers.InputLayer(input_shape=(7513,)), # 7513 features after preprocessing
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(630, activation='softmax') # 630 unique job titles
])

# Compile and train the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train_f, y_train_f, epochs=10, validation_data=(X_test_f, y_test_f)) # Use preprocessed data
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-7dd34c1c3da2> in <cell line: 62>()
#      60 # Compile and train the model
#      61 model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# ---> 62 model.fit(X_train_f, y_train_f, epochs=10, validation_data=(X_test_f, y_test_f)) # Use preprocessed data
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import pandas as pd

# Load your dataset
data = pd.read_csv('jobs.csv')

# Clean dataset
data_cleaned = data.drop('Unnamed: 0', axis=1)

# Label encode the target column 'Job Title'
label_encoder = LabelEncoder()
data_cleaned['Job Title'] = label_encoder.fit_transform(data_cleaned['Job Title'])

# Combine all feature columns into a single input
X = data_cleaned.drop('Job Title', axis=1)

# One-hot encode categorical features
X_encoded = pd.get_dummies(X, columns=['Job Salary', 'Job Experience Required', 'Key Skills', 'Role Category', 'Functional Area', 'Industry'])

# Define the target variable
y = data_cleaned['Job Title']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %%
# Define the neural network model
model = Sequential()
model.add(Dense(512, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(128, activation='relu'))
model.add(Dense(len(y.unique()), activation='softmax'))  # Output layer for multiclass classification

# Compile the model
model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=64, verbose=2)

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f'Test Accuracy: {test_acc * 100:.2f}%')
# Out:
# Epoch 1/50
# 338/338 - 24s - loss: 2.8250 - accuracy: 0.4292 - val_loss: 1.8945 - val_accuracy: 0.5481 - 24s/epoch - 70ms/step
# Epoch 2/50
# 338/338 - 22s - loss: 1.5214 - accuracy: 0.5846 - val_loss: 1.5370 - val_accuracy: 0.5744 - 22s/epoch - 65ms/step
# Epoch 3/50
# 338/338 - 22s - loss: 0.9708 - accuracy: 0.7159 - val_loss: 1.5860 - val_accuracy: 0.5657 - 22s/epoch - 65ms/step
# Epoch 4/50
# 338/338 - 22s - loss: 0.6155 - accuracy: 0.8248 - val_loss: 1.7550 - val_accuracy: 0.5370 - 22s/epoch - 65ms/step
# Epoch 5/50
# 338/338 - 22s - loss: 0.3857 - accuracy: 0.8941 - val_loss: 2.0197 - val_accuracy: 0.4863 - 22s/epoch - 65ms/step
# Epoch 6/50
# 338/338 - 22s - loss: 0.2632 - accuracy: 0.9278 - val_loss: 2.0796 - val_accuracy: 0.5087 - 22s/epoch - 65ms/step
# Epoch 7/50
# 338/338 - 23s - loss: 0.1840 - accuracy: 0.9499 - val_loss: 2.1362 - val_accuracy: 0.5354 - 23s/epoch - 67ms/step
# Epoch 8/50
# ...

# %%
import pickle

# Save the trained model
with open('job_title_model.pkl', 'wb') as file:
    pickle.dump(model, file)

# Save the Label Encoder for the target (Job Title)
with open('label_encoder.pkl', 'wb') as file:
    pickle.dump(label_encoder, file)

# Save the OneHotEncoder for features (if necessary)
with open('onehot_encoder.pkl', 'wb') as file:
    pickle.dump(X_encoded.columns, file)  # Saving column names for reference

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 664.7 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 28.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 58.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.1 MB/s eta 0:00:00
# ...

# %%
# Install necessary libraries
# !pip install tensorflow scikit-learn pandas streamlit pyngrok -q

import pandas as pd
import pickle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

from google.colab import files
uploaded = files.upload()

data = pd.read_csv('jobs.csv')

data_cleaned = data.drop('Unnamed: 0', axis=1)

label_encoder = LabelEncoder()
data_cleaned['Job Title'] = label_encoder.fit_transform(data_cleaned['Job Title'])

X = data_cleaned.drop('Job Title', axis=1)

X_encoded = pd.get_dummies(X, columns=['Job Salary', 'Job Experience Required', 'Key Skills', 'Role Category', 'Functional Area', 'Industry'])

y = data_cleaned['Job Title']

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

model = Sequential()
model.add(Dense(512, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(128, activation='relu'))
model.add(Dense(len(y.unique()), activation='softmax'))  # Output layer for multiclass classification

model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=64, verbose=2)

with open('job_title_model.pkl', 'wb') as file:
    pickle.dump(model, file)

with open('label_encoder.pkl', 'wb') as file:
    pickle.dump(label_encoder, file)

with open('onehot_encoder.pkl', 'wb') as file:
    pickle.dump(X_encoded.columns, file)

from google.colab import files
files.download('job_title_model.pkl')
files.download('label_encoder.pkl')
files.download('onehot_encoder.pkl')
# Out:
#      <input type="file" id="files-42379588-0320-49a5-9e29-efa239948c4c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-42379588-0320-49a5-9e29-efa239948c4c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Install necessary libraries
# !pip install streamlit pyngrok -q

# %%
# Step 1: Install Streamlit and pyngrok

# Step 2: Add your ngrok authtoken
# Replace YOUR_AUTHTOKEN with your actual ngrok token
# !ngrok config add-authtoken 2mtDzNRY1WSoqwbLwFnjPrYJOyy_5ty3SyQYMUVQZP5Z8dP3f

# Step 3: Write the Streamlit app to a file
with open('app.py', 'w') as f:
    f.write("""
import streamlit as st

st.title('Hello from Streamlit!')
st.write('This Streamlit app is running on Colab.')
    """)

# Step 4: Start the Streamlit app and ngrok tunnel
from pyngrok import ngrok
import os

# Run the Streamlit app in the background
os.system('streamlit run app.py &')

# Start the ngrok tunnel
public_url = ngrok.connect(8501)  # This connects to the default Streamlit port
print(f"Streamlit app is live at: {public_url}")
# Out:
# /bin/bash: line 1: ngrok: command not found
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-bdf7eb79678c> in <cell line: 17>()
#      15
#      16 # Step 4: Start the Streamlit app and ngrok tunnel
# ---> 17 from pyngrok import ngrok
#      18 import os
#      19
#
# ModuleNotFoundError: No module named 'pyngrok'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Step 1: Install necessary libraries
# !pip install streamlit pyngrok -q

# Step 2: Import necessary libraries
import streamlit as st
import pickle
import pandas as pd
import numpy as np
from pyngrok import ngrok
import os

# Step 3: Load the saved model and encoders
# Ensure the file paths are correct and the files exist.
with open('/content/job_title_model (1).pkl', 'rb') as file:
    model = pickle.load(file)

with open('/content/label_encoder (2).pkl', 'rb') as file:
    label_encoder = pickle.load(file)

with open('/content/onehot_encoder (1).pkl', 'rb') as file:
    columns = pickle.load(file)

# Step 4: Create a function for the Streamlit app
def run_app():
    # Streamlit interface
    st.title('Job Title Prediction')

    # Input fields for features
    job_salary = st.text_input('Job Salary (e.g., "2,00,000 - 4,00,000 PA")')
    job_experience = st.text_input('Experience Required (e.g., "2 - 5 yrs")')
    key_skills = st.text_input('Key Skills (comma-separated)')
    role_category = st.text_input('Role Category (e.g., "Programming & Design")')
    functional_area = st.text_input('Functional Area (e.g., "IT Software - QA & Testing")')
    industry = st.text_input('Industry (e.g., "IT-Software, Software Services")')

    # Predict button
    if st.button('Predict Job Title'):
        # Prepare input data for prediction
        input_data = pd.DataFrame({
            'Job Salary': [job_salary],
            'Job Experience Required': [job_experience],
            'Key Skills': [key_skills],
            'Role Category': [role_category],
            'Functional Area': [functional_area],
            'Industry': [industry]
        })

        # One-hot encode the input data based on saved columns
        input_data_encoded = pd.get_dummies(input_data).reindex(columns=columns, fill_value=0)

        # Make prediction
        prediction = model.predict(input_data_encoded)
        predicted_label = label_encoder.inverse_transform([np.argmax(prediction)])

        st.write(f'Predicted Job Title: {predicted_label[0]}')

# Step 5: Authenticate ngrok and run the app
ngrok_auth_token = "<2mtDzNRY1WSoqwbLwFnjPrYJOyy_5ty3SyQYMUVQZP5Z8dP3f>"  # Replace <YOUR_AUTHTOKEN> with your actual ngrok token
# !ngrok config add-authtoken {ngrok_auth_token}

from pyngrok import ngrok
import os

# Run the Streamlit app in the background
os.system('streamlit run app.py &')

# Start the ngrok tunnel
public_url = ngrok.connect(8501)  # This connects to the default Streamlit port
print(f"Streamlit app is live at: {public_url}")
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# <ipython-input-3-8af387dec5d4> in <cell line: 14>()
#      13 # Ensure the file paths are correct and the files exist.
#      14 with open('/content/job_title_model (1).pkl', 'rb') as file:
# ---> 15     model = pickle.load(file)
#      16
#      17 with open('/content/label_encoder (2).pkl', 'rb') as file:
#
# UnpicklingError: pickle data was truncated

# %%
from sklearn.naive_bayes import MultinomialNB
mnb=MultinomialNB()
mnb.fit(X_train,y_train)
y_pred1=mnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))

# %%
# Step 1: Install necessary libraries
# !pip install streamlit pyngrok -q

# Step 2: Import necessary libraries
import streamlit as st
import pickle
import pandas as pd
import numpy as np
from pyngrok import ngrok
import os

# Step 3: Load the saved model and encoders
# Ensure the file paths are correct and the files exist.
with open('/content/job_title_model.pkl', 'rb') as file:
    model = pickle.load(file)

with open('/content/label_encoder.pkl', 'rb') as file:
    label_encoder = pickle.load(file)

with open('/content/onehot_encoder.pkl', 'rb') as file:
    columns = pickle.load(file)

# Step 4: Create a function for the Streamlit app
def run_app():
    # Streamlit interface
    st.title('Job Title Prediction')
    st.markdown("""
    <style>
        .reportview-container {
            background: #F0F0F5;
        }
        .sidebar .sidebar-content {
            background: #F0F0F5;
        }
    </style>
    """, unsafe_allow_html=True)

    # Input fields for features
    job_salary = st.text_input('Job Salary (e.g., "2,00,000 - 4,00,000 PA")')
    job_experience = st.text_input('Experience Required (e.g., "2 - 5 yrs")')
    key_skills = st.text_input('Key Skills (comma-separated)')
    role_category = st.text_input('Role Category (e.g., "Programming & Design")')
    functional_area = st.text_input('Functional Area (e.g., "IT Software - QA & Testing")')
    industry = st.text_input('Industry (e.g., "IT-Software, Software Services")')

    # Predict button
    if st.button('Predict Job Title'):
        # Prepare input data for prediction
        input_data = pd.DataFrame({
            'Job Salary': [job_salary],
            'Job Experience Required': [job_experience],
            'Key Skills': [key_skills],
            'Role Category': [role_category],
            'Functional Area': [functional_area],
            'Industry': [industry]
        })

        # Convert Job Salary and Experience Required to numerical format if applicable
        input_data['Job Salary'] = input_data['Job Salary'].str.replace(',', '').str.extract('(\d+)')[0].astype(float)
        input_data['Job Experience Required'] = input_data['Job Experience Required'].str.extract('(\d+)')[0].astype(float)

        # One-hot encode the input data based on saved columns
        input_data_encoded = pd.get_dummies(input_data).reindex(columns=columns, fill_value=0)

        # Ensure input data is of type float32
        input_data_encoded = input_data_encoded.astype('float32')

        # Make prediction
        prediction = model.predict(input_data_encoded)
        predicted_label = label_encoder.inverse_transform([np.argmax(prediction)])

        # Display the prediction result
        st.success(f'### Predicted Job Title: **{predicted_label[0]}**')

# Step 5: Authenticate ngrok and run the app
ngrok_auth_token = "<2mtDzNRY1WSoqwbLwFnjPrYJOyy_5ty3SyQYMUVQZP5Z8dP3f>"  # Replace <YOUR_AUTHTOKEN> with your actual ngrok token
# !ngrok config add-authtoken {ngrok_auth_token}

# Run the Streamlit app in the background
os.system('streamlit run app.py &')

# Start the ngrok tunnel
public_url = ngrok.connect(8501)  # This connects to the default Streamlit port
print(f"Streamlit app is live at: {public_url}")

# Run the app
run_app()
